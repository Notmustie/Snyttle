# %%
# !pip install -U langgraph langchain langchain-anthropic anthropic streamlit python-dotenv

# %%
# !pip install -U anthropic

# %%
from dotenv import load_dotenv
import os

load_dotenv(".env")

key = os.getenv("ANTHROPIC_API_KEY")

print("Exists:", key is not None)
print("Prefix:", key[:10] if key else None)
# Out:
# Exists: True
# Prefix: your_api_k

# %%
import os
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))

models = client.models.list()

for model in models.data:
    print(model.id)
# Out:
# claude-opus-5
# claude-sonnet-5
# claude-fable-5
# claude-opus-4-8
# claude-opus-4-7
# claude-sonnet-4-6
# claude-opus-4-6
# claude-opus-4-5-20251101
# claude-haiku-4-5-20251001
# claude-sonnet-4-5-20250929

# %%
import os
from dotenv import load_dotenv
from langchain_anthropic import ChatAnthropic

load_dotenv()

llm = ChatAnthropic(
    model="claude-haiku-4-5-20251001",
    temperature=0
)

response = llm.invoke(
    "Explain in one sentence what a multi-agent AI system is."
)

print(response.content)
# Out:
# A multi-agent AI system is a network of independent AI agents that interact with each other and their environment to solve problems collaboratively or competitively.
